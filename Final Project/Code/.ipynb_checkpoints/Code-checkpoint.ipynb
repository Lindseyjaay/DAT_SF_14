# %% [markdown]
# # PART 1: THE SETUP

# %% [markdown]
# Installing the necessary packages

# %%
# !pip install --upgrade pip seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# You are using pip version 7.0.3, however version 7.1.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
#     100% |████████████████████████████████| 1.1MB 171kB/s
# ...
#     100% |████████████████████████████████| 147kB 1.1MB/s
# ...
#   Found existing installation: pip 7.0.3
#     Uninstalling pip-7.0.3:
#       Successfully uninstalled pip-7.0.3
#   Found existing installation: seaborn 0.5.1
#     Uninstalling seaborn-0.5.1:
#       Successfully uninstalled seaborn-0.5.1
#   Running setup.py install for seaborn
# ...

# %% [markdown]
# Importing my clean data as a CSV file.

# %%
data = pd.read_csv("/Users/owner/desktop/ecb_data.csv")

# %% [markdown]
# Getting a quick glance at the cleaned data

# %%
data.head()
# Out:
#          apn buillding_address  building_zip           neighborhood  \
# 0   0326/003     135 POWELL ST         94102  Downtown/Civic Center
# 1   1401/002   3132 CLEMENT ST         94121               Seacliff
# 2  4347A/003     2090 Evan St.         94124                Bayview
# 3   3780/078    836 BRANNAN ST         94103        South of Market
# 4   3511/093   40 LAFAYETTE ST         94103        South of Market
#
#   floor_area sqft_group floor_area_group  year_built year_built_group  \
# 0     18,990     10-25K           10-20K        1909        1900-1909
# 1     16,669     10-25K           10-20K        2002        2000-2009
# 2    119,900       50K+         100-200K        1956        1950-1959
# 3     33,549     25-50K           30-40K        2001        2000-2009
# 4    127,900       50K+         100-200K        1934        1930-1939
#
#   benchmark_2010_status            ...               land_use total_uses cie  \
# ...

# %%
from sklearn import preprocessing
import numpy as np
import scipy
import csv
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import StratifiedKFold

# %% [markdown]
# I need to change my qualitative data into quantitative data. To do this, I used label encoding.

# %%
#creating a variable for labeling
label = preprocessing.LabelEncoder()

# %%
#transforming the data from categorical to numerical
data.building_zip = label.fit_transform(data.building_zip)
data.neighborhood = label.fit_transform(data.neighborhood)
data.sqft_group = label.fit_transform(data.sqft_group)
data.floor_area_group = label.fit_transform(data.floor_area_group)
data.yearbuiltgroup = label.fit_transform(data.year_built_group)
data.benchmark_2010_status = label.fit_transform(data.benchmark_2010_status)
data.benchmark_2011_status = label.fit_transform(data.benchmark_2011_status)
data.benchmark_2012_status = label.fit_transform(data.benchmark_2012_status)
data.benchmark_2013_status = label.fit_transform(data.benchmark_2013_status)
data.benchmark_2014_status = label.fit_transform(data.benchmark_2014_status)
data.land_use = label.fit_transform(data.land_use)
data.construction_description = label.fit_transform(data.construction_description)
data.d = label.fit_transform(data.description)

# %%
#Viewing the trnsformed data
data.head()
# Out:
#          apn buillding_address  building_zip  neighborhood floor_area  \
# 0   0326/003     135 POWELL ST             0             6     18,990
# 1   1401/002   3132 CLEMENT ST            15            29     16,669
# 2  4347A/003     2090 Evan St.            18             0    119,900
# 3   3780/078    836 BRANNAN ST             1            30     33,549
# 4   3511/093   40 LAFAYETTE ST             1            30    127,900
#
#    sqft_group  floor_area_group  year_built year_built_group  \
# 0           0                 0        1909        1900-1909
# 1           0                 0        2002        2000-2009
# 2           2                 1        1956        1950-1959
# 3           1                 5        2001        2000-2009
# 4           2                 1        1934        1930-1939
#
#    benchmark_2010_status            ...             land_use  total_uses  cie  \
# 0                      0            ...                   10       24671    0
# ...

# %%
# Splitting data into features and outcomes
X = data[cols]
y = data[outcome]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-bd25825fed15> in <module>()
#       1 # Splitting data into features and outcomes
# ----> 2 X = data[cols]
#       3 y = data[outcome]
#
# NameError: name 'cols' is not defined

# %%
# Import train_test_split and pass split data into a new instance
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#viewing the splits
print X_train
print y_train
print X_test
print y_test
# Out:
# [['0260/010' '300 MONTGOMERY ST' 2 ..., 'A' 7 'O']
#  ['0929/012' '2324 CHESTNUT ST' 17 ..., 'F' 8 'C']
#  ['3575/091' '2101 MISSION ST' 7 ..., 'C' 3 'O']
#  ...,
#  ['0227/011' '640 SACRAMENTO ST' 8 ..., 'B' 4 'O']
#  ['3510/057' '1453 MISSION ST' 1 ..., 'B' 4 'O']
#  ['0173/005' '607 FRONT ST' 8 ..., 'C' 3 'O']]
# [[33]
#  [ 9]
#  [33]
#  ...,
#  [33]
#  [33]
#  [33]]
# [['3952/001' '2 CONNECTICUT ST' 4 ..., 'F' 8 'O']
#  ['4356/001' '3101 3RD ST' 18 ..., 'C' 3 'I']
#  ['0289/009' '180 MONTGOMERY ST' 2 ..., 'F' 8 'O']
#  ...,
#  ['3754/017' '385 7TH ST' 1 ..., '0' 1 'O']
#  ['1064/032' '3360 GEARY BLVD' 14 ..., 'F' 8 'O']
#  ['3733/091' '363 CLEMENTINA ST' 1 ..., 'C' 3 'I']]
# [[33]
#  [24]
#  [33]
#  [22]
#  [33]
#  [34]
#  [24]
#  [20]
#  [24]
#  [ 9]
#  [33]
#  [ 6]
#  [22]
#  [33]
#  [ 9]
#  [ 9]
#  [33]
#  [33]
#  [ 9]
#  [24]
#  [24]
#  [33]
#  [24]
#  [24]
#  [47]
#  [33]
#  [16]
#  [ 4]
#  [ 0]
#  [ 0]
#  [ 6]
#  [22]
#  [ 0]
#  [ 0]
#  [ 9]
#  [ 9]
#  [33]
#  [33]
#  [22]
# ...

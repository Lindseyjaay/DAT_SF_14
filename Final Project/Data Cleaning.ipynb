# %%
# !pip install --upgrade pip seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from bokeh.charts import Bar
from bokeh.plotting import *
# Out:
# Requirement already up-to-date: pip in /Users/owner/anaconda/lib/python2.7/site-packages
# Requirement already up-to-date: seaborn in /Users/owner/anaconda/lib/python2.7/site-packages

# %%
#Importing my CSV
data = pd.read_csv("/Users/owner/desktop/ecb_data.csv")

# %%
#Getting a quick glance at the data
data.head()
# Out:
#          APN     bldg_address  bldg_zip           neighborhood floor_area  \
# 0   0326/003    135 POWELL ST     94102  Downtown/Civic Center     18,990
# 1   1401/002  3132 CLEMENT ST     94121               Seacliff     16,669
# 2  4347A/003    2090 Evan St.     94124                Bayview    119,900
# 3   3780/078   836 BRANNAN ST     94103        South of Market     33,549
# 4   3511/093  40 LAFAYETTE ST     94103        South of Market    127,900
#
#   sqft_group floor_area_group  year_built year_built_group  \
# 0     10-25K           10-20K        1909        1900-1909
# 1     10-25K           10-20K        2002        2000-2009
# 2       50K+         100-200K        1956        1950-1959
# 3     25-50K           30-40K        2001        2000-2009
# 4       50K+         100-200K        1934        1930-1939
#
#   bmark_2010_due_date        ...         cie med mips retail    pdr visitor  \
# 0                 NaN        ...           0   0    0  24671      0       0
# ...

# %%
#Calculating the average year built to populate null values for the Year Built column.
average_year_built = data['year_built'].mean()
average_year_built
#Had trouble filling null values here, so I manually went into my csv and populated all
#blank cells under year built with the average year built.
# Out:
# 1939.0695931477517

# %%
data.year_built.hist(bins = 60);
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 74

# %%
data['year_built_group'].value_counts().plot(kind = 'barh')

# %%
data['neighborhood'].value_counts().plot(kind = 'barh')

# %%
data['bldg_zip'].value_counts().plot(kind = 'barh')

# %%
data['sqft_group'].value_counts().plot(kind = 'barh')

# %%
data['floor_area_group'].value_counts().plot(kind = 'barh')
